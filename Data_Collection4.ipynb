# %%
import requests
import base64
import re
import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
client_id= "aaa1fe47695741eb819d04efa37e4a69"
client_secret= "0bf689017bfd44a4ad5270d9029b04f2"
redirect_uri = 'http://localhost:8888/callback'
scope = "user-library-read"

# %%
#Base64 encode the client ID and client secret
client_credentials = f"{client_id}:{client_secret}"
client_credentials_base64 = base64.b64encode(client_credentials.encode())

# %%
# Request the acces token
token_url = 'https://accounts.spotify.com/api/token'
headers = {
    'Authorization': f'Basic {client_credentials_base64.decode()}'
}
data = {
    'grant_type': 'client_credentials'
}
response = requests.post(token_url, data=data, headers=headers)
if response.status_code == 200:
    access_token = response.json()['access_token']
    print(access_token)
else:
    print("Error")
    exit()
# Out:
# BQApoRTwL77OKNyp6J6MtIjTDcTAl6UJdir8TPi7oSai-yTWBX6iQvGf6ryr7xlXFf-UDd54womD-9cn9BuwBiEDQqfZNvBk-zUqISZpyJ6OIaGfPQE

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth
auth_manager = spotipy.oauth2.SpotifyOAuth(
    client_id='your_client_id',
    client_secret='your_client_secret',
    redirect_uri='your_redirect_uri',
    scope='user-library-read', 
)

# %%
def get_playlist_data(playlist_id,access_token):
    # setup spotify with the access token
    sp = spotipy.Spotify(auth=access_token)
    
    #Get the track from the playlist
    playlist_tracks = sp.playlist_tracks(playlist_id, fields='items(track(id, name, artists, album(id, name)))')
    
    #Extract relevent information and store in a list of dictionaries
    data = []
    for track_info in playlist_tracks['items']:
        track = track_info['track']
        track_name = track['name']
        artists = ', '.join([artist['name'] for artist in track['artists']])
        album_name = track['album']['name']
        album_id = track['album']['id']
        track_id = track['id']
        
        # Get audio features for the track
        audio_features = sp.audio_features(track_id)[0] if track_id != 'Not available' else None
        
        # Get release date of the album
        try:
            album_info = sp.album(album_id) if album_id != 'Not available' else None
            release_date = album_info['release_date'] if album_info else None
        except:
            release_date = None
            
        # Get popularity of the track
        try:
            track_info = sp.track(tack_id) if track_id != 'Not available' else None
            popularity = track_info['popularity'] if track_info else None
        except:
            popularity = None
            
        # Add additional track information to the track data
        track_data = {
            'Track Name' : track_name,
            'Artists' : artists,
            'Album Name': album_name,
            'Album Id': album_id,
            'Track ID':track_id,
            'Popularity':popularity,
            'Release Date':release_date,
            'Duration (ms)': audio_features['duration_ms'] if audio_features else None,
            'Explicit URLs': track_info.get('external_urls',{}).get('splotify',None),
            'Danceability': audio_features['danceability'] if audio_features else None,
            'Energy': audio_features['energy'] if audio_features else None,
            'Key': audio_features['key'] if audio_features else None,
            'Loudness': audio_features['loudness'] if audio_features else None,
            'Mode': audio_features['mode'] if audio_features else None,
            'Speechiness': audio_features['speechiness'] if audio_features else None,
            'Acousticness': audio_features['acousticness'] if audio_features else None,
            'Instrumentalness': audio_features['instrumentalness'] if audio_features else None,
            'Liveness': audio_features['liveness'] if audio_features else None,
            'Valence': audio_features['valence'] if audio_features else None,
            'Tempo': audio_features['tempo'] if audio_features else None,
        }
        
        data.append(track_data)
        
    # Create a pandas DataFrame from the list of dictionaries
    df = pd.DataFrame(data)
    
    return df

# %%
playlist_id4 ='5VcubOjfAeoDcSZtU3fYpq'
song1 = get_playlist_data(playlist_id4,access_token)

# %%
playlist_id5 ='35HzZ7pFLnND0euwfBcjDB'
song2 = get_playlist_data(playlist_id5,access_token)

# %%
playlist_id6 ='3PZIOetEb4VPqPIgsKcFaT'
song3 = get_playlist_data(playlist_id6,access_token)

# %%
playlist_id7 ='1QZWk23l6ryKMlgvQ4KIp0'
song4 = get_playlist_data(playlist_id7,access_token)

# %%
playlist_id8 ='4RwcWjMLNd0wNNWNl0OWdH'
song5 = get_playlist_data(playlist_id8,access_token)

# %%
playlist_id9 ='5j31GbOdldi3mItLuIinRQ'
song6 = get_playlist_data(playlist_id9,access_token)

# %%
playlist_id10 ='3Tv9xiR2d5zPtuURz6IHEq'
song7 = get_playlist_data(playlist_id10,access_token)

# %%
playlist_id11 ='7DDo4BQbEDFZuc9ukBqVCq'
song8 = get_playlist_data(playlist_id11,access_token)

# %%
playlist_id12 ='1aHgyElCJtA7LXaOjKTjMA'
song9 = get_playlist_data(playlist_id12,access_token)

# %%
playlist_id13 ='7kbFeAhFiA1wP2ocuBMuAx'
song10 = get_playlist_data(playlist_id13,access_token)

# %%
playlist_id14 ='3qpwui77CQU15i9UpG28eR'
song11 = get_playlist_data(playlist_id14,access_token)

# %%
playlist_id15 ='26veeUIuxwnCpUTCBEW5iM'
song12 = get_playlist_data(playlist_id15,access_token)

# %%
playlist_id16 ='37i9dQZF1DZ06evO0Kc0i8'
song13 = get_playlist_data(playlist_id16,access_token)

# %%
song11.tail(10)
# Out:
#                                            Track Name  \
# 26                                       Chasing Cars
# 27                                    I Won't Give Up
# 28                                       It Will Rain
# 29                                      Jar of Hearts
# 30                                  Dancing On My Own
# 31  Safe & Sound - The Hunger Games/Soundtrack Ver...
# 32                                 How to Save a Life
# 33                                            Jealous
# 34          i hate u, i love u (feat. olivia o'brien)
# 35                                A Drop in the Ocean
#
#                          Artists  \
# 26                   Snow Patrol
# 27                    Jason Mraz
# 28                    Bruno Mars
# 29               Christina Perri
# 30                   Calum Scott
# 31  Taylor Swift, The Civil Wars
# 32                      The Fray
# 33                      Labrinth
# 34         gnash, Olivia O'Brien
# ...

# %%
data = pd.concat([song1,song2,song3,song4,song5,song6,song7,song8,song9,song10,song11,song12, song13])
data.drop_duplicates(inplace=True, keep='last')
data.tail(1000)
# Out:
#                                       Track Name  \
# 0                         can't leave without it
# 1                                         Runnin
# 2                                Glock In My Lap
# 3   Surround Sound (feat. 21 Savage & Baby Tate)
# 4             Rich Nigga Shit (feat. Young Thug)
# ..                                           ...
# 45                                   DE CAROLINA
# 46           Baila Conmigo (with Rauw Alejandro)
# 47                            Dream Girl - Remix
# 48                                        Besalo
# 49                                DIME QUIÉN????
#
#                                 Artists                            Album Name  \
# 0                             21 Savage                          i am > i was
# 1               21 Savage, Metro Boomin                        SAVAGE MODE II
# 2               21 Savage, Metro Boomin                        SAVAGE MODE II
# ...

# %%
data.to_csv('data4.csv', index=False)

# %%
data[data['Track Name']== "Elevator"]
# Out:
#    Track Name Artists Album Name                Album Id  \
# 13   Elevator  BAEKHO   Elevator  7qAmKSszPEYHUNhETGGhSI
#
#                   Track ID Popularity Release Date  Duration (ms)  \
# 13  4rn1BxsXSSuZcgRa6thKYu       None   2023-08-31         163347
#
#    Explicit URLs  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 13          None         0.771   0.961    7    -3.601     0        0.191
#
#     Acousticness  Instrumentalness  Liveness  Valence    Tempo
# 13        0.0773               0.0     0.706    0.736  103.989
